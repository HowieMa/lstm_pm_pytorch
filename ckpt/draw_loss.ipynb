# %%
import json
import os
import sys
import matplotlib.pyplot as plt

# %%
aa=[]

for epoch in range(0,3):
    losses = os.listdir('/Users/mahaoyu/UCI/train_images/zzzz/loss_epoch'+str(epoch))
    losses.sort()

    loss=[]
    for l in losses:
        if l == '.DS_Store':
            continue 

        lossj = json.load(open('/Users/mahaoyu/UCI/train_images/zzzz/loss_epoch'+str(epoch) + '/' + l))

        n = l.split('.')[0][1:]
        a = lossj['total']
        loss.append([int(n), a])

    loss.sort()

    for l in loss:
        aa.append(l[1])

plt.plot(aa)
